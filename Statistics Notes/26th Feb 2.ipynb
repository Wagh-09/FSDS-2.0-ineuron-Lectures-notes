# %%
data=[23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
import seaborn as sns
sns.histplot(data)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
data_copy=data.copy()

# %%
data_copy.sort()

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
sns.histplot(data,kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
import pandas as pd
data2=pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/Statistics_With_Python/main/Iris.csv")
data2.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.histplot(np.log(data2["SepalLengthCm"]),kde=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6228/2878780496.py in <module>
# ----> 1 sns.histplot(np.log(data2["SepalLengthCm"]),kde=True)
#
# NameError: name 'np' is not defined

# %%
sns.histplot(data2["SepalWidthCm"],kde=True)

# %%
#Perfect normal distribution

# %%
sns.histplot(data2["PetalLengthCm"],kde=True)
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Count'>

# %%
data_copy.append(17)

# %%
sns.histplot(data_copy,kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(data2["PetalWidthCm"],kde=True)
# Out:
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='Count'>

# %%
import numpy as np
s=np.random.normal(0.5,0.2,1000)

# %%
sns.histplot(s,kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
mu=3.0
sigma=1.0
p=np.random.lognormal(mu,sigma,1000)

# %%
sns.histplot(p,kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(np.log(p),kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
import matplotlib as plt
import scipy.stats as stat
import pylab
def plot_data(sample):
    pt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample)
    plt.subplot(1,2,2)
    stat.probplot(sample,dist='norm',plot=pylab)
    plt.show()

# %%
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab
def plot_data(sample):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample,kde=True)
    plt.subplot(1,2,2)
    stat.probplot(sample,dist='norm',plot=pylab)
    plt.show()

# %%
plot_data(s)

# %%
plot_data(data)

# %%
plot_data(p)

# %%
plot_data(np.log(p))

# %%
import pandas as pd
data3=pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/Statistics_With_Python/main/Titanic.csv")

# %%
data3.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# !pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Using cached pandas_profiling-3.6.6-py2.py3-none-any.whl (324 kB)
# Collecting ydata-profiling
#   Using cached ydata_profiling-4.0.0-py2.py3-none-any.whl (344 kB)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in c:\users\dell\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (1.20.3)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in c:\users\dell\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (0.11.2)
# Requirement already satisfied: statsmodels<0.14,>=0.13.2 in c:\users\dell\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (0.13.5)
# Requirement already satisfied: matplotlib<3.7,>=3.2 in c:\users\dell\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (3.4.3)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\dell\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (2.11.3)
# Requirement already satisfied: multimethod<1.10,>=1.4 in c:\users\dell\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (1.9.1)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\dell\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (6.0)
# Collecting htmlmin==0.1.12
#   Using cached htmlmin-0.1.12-py3-none-any.whl
# Requirement already satisfied: typeguard<2.14,>=2.13.2 in c:\users\dell\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (2.13.3)
# Collecting pydantic<1.11,>=1.8.1
#   Using cached pydantic-1.10.5-cp39-cp39-win_amd64.whl (2.2 MB)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in c:\users\dell\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (0.7.5)
# Requirement already satisfied: tqdm<4.65,>=4.48.2 in c:\users\dell\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (4.62.3)
# Requirement already satisfied: pandas!=1.4.0,<1.6,>1.1 in c:\users\dell\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (1.3.4)
# Collecting phik<0.13,>=0.11.1
#   Using cached phik-0.12.3-cp39-cp39-win_amd64.whl (663 kB)
# Requirement already satisfied: requests<2.29,>=2.24.0 in c:\users\dell\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (2.26.0)
# Requirement already satisfied: scipy<1.10,>=1.4.1 in c:\users\dell\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (1.7.1)
# Requirement already satisfied: networkx>=2.4 in c:\users\dell\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (2.6.3)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\dell\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (21.2.0)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in c:\users\dell\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (0.2.0)
# Requirement already satisfied: imagehash in c:\users\dell\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (4.3.1)
# Requirement already satisfied: Pillow in c:\users\dell\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (8.4.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\dell\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas-profiling) (1.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (0.10.0)
# Requirement already satisfied: six in c:\users\dell\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (1.16.0)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\dell\anaconda3\lib\site-packages)
# Requirement already satisfied: pytz>=2017.3 in c:\users\dell\anaconda3\lib\site-packages (from pandas!=1.4.0,<1.6,>1.1->ydata-profiling->pandas-profiling) (2021.3)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\dell\anaconda3\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas-profiling) (1.1.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\dell\anaconda3\lib\site-packages (from pydantic<1.11,>=1.8.1->ydata-profiling->pandas-profiling) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (1.26.7)
# Requirement already satisfied: packaging>=21.3 in c:\users\dell\anaconda3\lib\site-packages (from statsmodels<0.14,>=0.13.2->ydata-profiling->pandas-profiling) (23.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\dell\anaconda3\lib\site-packages (from statsmodels<0.14,>=0.13.2->ydata-profiling->pandas-profiling) (0.5.2)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\lib\site-packages (from tqdm<4.65,>=4.48.2->ydata-profiling->pandas-profiling) (0.4.4)
# Requirement already satisfied: PyWavelets in c:\users\dell\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (1.1.1)
# Installing collected packages: pydantic, phik, htmlmin, ydata-profiling, pandas-profiling
# Successfully installed htmlmin-0.1.12 pandas-profiling-3.6.6 phik-0.12.3 pydantic-1.10.5 ydata-profiling-4.0.0

# %%
import pandas_profiling 
profile = data3.profile_report()

# %%
profile.to_file(output_file="output.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
